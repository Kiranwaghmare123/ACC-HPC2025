# %%
#Discrete data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Number_of_Students': [25, 30, 28, 32, 27]}
df = pd.DataFrame(data)
df
# Out:
#    Number_of_Students
# 0                  25
# 1                  30
# 2                  28
# 3                  32
# 4                  27

# %%
#Continuous data
data = {'Height_cm': [167.5, 182.0, 176.3, 158.9, 170.2]}
df = pd.DataFrame(data)
df
# Out:
#    Height_cm
# 0      167.5
# 1      182.0
# 2      176.3
# 3      158.9
# 4      170.2

# %%
#Nominal data
data = {'Gender': ['Male', 'Female', 'Female', 'Male', 'Male']}
df = pd.DataFrame(data)
df
# Out:
#    Gender
# 0    Male
# 1  Female
# 2  Female
# 3    Male
# 4    Male

# %%
#Ordinal data
data = {'Education_Level': ['Bachelor', 'Master', 'PhD', 'High School', 'Bachelor']}
df = pd.DataFrame(data)
df
# Out:
#   Education_Level
# 0        Bachelor
# 1          Master
# 2             PhD
# 3     High School
# 4        Bachelor

# %%
#Structured data
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
print(data)
df = pd.DataFrame(data)
df
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Los Angeles', 'Chicago']}
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#Unstructured data
text_data = ["This is a sample sentence for HPC studnets.", "AI/ML/Data science is fascinating.", "Python is a versatile language."]
text_data
# Out:
# ['This is a sample sentence for HPC studnets.',
#  'AI/ML/Data science is fascinating.',
#  'Python is a versatile language.']

# %%
#Semistructured data
import json
json_data = {
    "employees": [
        {"name": "Ram", "age": 30, "city": "New York"},
        {"name": "Sita", "age": 22, "city": "London"},
        {"name": "Laxman", "age": 32, "city": "Chicago"}
    ]
}
json_data
# Out:
# {'employees': [{'name': 'Ram', 'age': 30, 'city': 'New York'},
#   {'name': 'Sita', 'age': 22, 'city': 'London'},
#   {'name': 'Laxman', 'age': 32, 'city': 'Chicago'}]}

# %%
print(json.dumps(json_data))
# Out:
# {"employees": [{"name": "Ram", "age": 30, "city": "New York"}, {"name": "Sita", "age": 22, "city": "London"}, {"name": "Laxman", "age": 32, "city": "Chicago"}]}

# %%
#Series data
s = pd.Series([1,2,3], index=['a','b','c'])
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
df1 = pd.DataFrame({'A':[1,2], 'B':[3,4]})
df2 = pd.DataFrame({'A':[1,2], 'B1':[5,6]})
df11 = pd.merge(df1, df2, on='A')
df11
# Out:
#    A  B  B1
# 0  1  3   5
# 1  2  4   6

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
print(data)
df = pd.DataFrame(data)
df
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['New York', 'Los Angeles', 'Chicago']}
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
#Selecting data
df['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
#Selection and Filtering
[df['Age'] > 25]
# Out:
# [0    False
#  1     True
#  2     True
#  Name: Age, dtype: bool]

# %%
# Handling Missing values
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, np.nan, 30, 22],
    "Score": [85, 90, np.nan, 75]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  30.0    NaN
# 3    David  22.0   75.0

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
# Out:
# /tmp/ipython-input-1809399462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df["Score"].fillna(df["Score"].median(), inplace=True)
# Out:
# /tmp/ipython-input-1700578021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(df["Score"].median(), inplace=True)

# %%
df
# Out:
#       Name        Age  Score
# 0    Alice  25.000000   85.0
# 1      Bob  25.666667   90.0
# 2  Charlie  30.000000   85.0
# 3    David  22.000000   75.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      float64
#  2   Score   4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 228.0+ bytes

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda', np.nan, 'Tom', 'Anna'],
    'Age': [28, 22, 35, np.nan, 45, 30, 22],
    'Salary': [50000, 54000, np.nan, 66000, 71000, 58000, 54000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name   Age   Salary
# 0   John  28.0  50000.0
# 1   Anna  22.0  54000.0
# 2  Peter  35.0      NaN
# 3  Linda   NaN  66000.0
# 4    NaN  45.0  71000.0
# 5    Tom  30.0  58000.0
# 6   Anna  22.0  54000.0

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-3445616279.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)
#     Name        Age   Salary
# 0   John  28.000000  50000.0
# 1   Anna  22.000000  54000.0
# 2  Peter  35.000000      NaN
# 3  Linda  30.333333  66000.0
# 4    NaN  45.000000  71000.0
# 5    Tom  30.000000  58000.0
# 6   Anna  22.000000  54000.0

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David","Simran","Simon"],

    "Score": [85, 90, 90, 75,75,75]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     90
# 3    David     75
# 4   Simran     75
# 5    Simon     75

# %%
df = df.drop_duplicates()
df
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     90
# 3    David     75
# 4   Simran     75
# 5    Simon     75

# %%
#Data Preproessing
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2. Import dataset
dataset = pd.read_csv('/content/Data.csv')
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %%
dataset.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
#Independent variables
X = dataset.iloc[:,:-1].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
#Dependent variables
y = dataset.iloc[:,-1].values
y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
#Handling Missing values
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:,1:3])
X[:,1:3] = imputer.transform(X[:,1:3])
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, 63777.77777777778],
#        ['France', 35.0, 58000.0],
#        ['Spain', 38.77777777777778, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
#Splitting of data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
# array([['Germany', 40.0, 63777.77777777778],
#        ['France', 37.0, 67000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Spain', 38.77777777777778, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Spain', 38.0, 61000.0],
#        ['France', 44.0, 72000.0],
#        ['France', 35.0, 58000.0]], dtype=object)

# %%
X_test
# Out:
# array([['Germany', 30.0, 54000.0],
#        ['Germany', 50.0, 83000.0]], dtype=object)

# %%
#Encoding Categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:,0] = labelencoder.fit_transform(X[:,0])
X
# Out:
# array([[0, 44.0, 72000.0],
#        [2, 27.0, 48000.0],
#        [1, 30.0, 54000.0],
#        [2, 38.0, 61000.0],
#        [1, 40.0, 63777.77777777778],
#        [0, 35.0, 58000.0],
#        [2, 38.77777777777778, 52000.0],
#        [0, 48.0, 79000.0],
#        [1, 50.0, 83000.0],
#        [0, 37.0, 67000.0]], dtype=object)

# %%
#OneHotEncoding
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X1 = np.array(columnTransformer.fit_transform(X), dtype=np.str_)
X1
# Out:
# array([['1.0', '0.0', '0.0', '44.0', '72000.0'],
#        ['0.0', '0.0', '1.0', '27.0', '48000.0'],
#        ['0.0', '1.0', '0.0', '30.0', '54000.0'],
#        ['0.0', '0.0', '1.0', '38.0', '61000.0'],
#        ['0.0', '1.0', '0.0', '40.0', '63777.77777777778'],
#        ['1.0', '0.0', '0.0', '35.0', '58000.0'],
#        ['0.0', '0.0', '1.0', '38.77777777777778', '52000.0'],
#        ['1.0', '0.0', '0.0', '48.0', '79000.0'],
#        ['0.0', '1.0', '0.0', '50.0', '83000.0'],
#        ['1.0', '0.0', '0.0', '37.0', '67000.0']], dtype='<U17')

# %%
# feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1 = sc.fit_transform(X1)
X1
# Out:
# array([[ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#          7.58874362e-01,  7.49473254e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#         -1.71150388e+00, -1.43817841e+00],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#         -1.27555478e+00, -8.91265492e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#         -1.13023841e-01, -2.53200424e-01],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#          1.77608893e-01,  6.63219199e-16],
#        [ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#         -5.48972942e-01, -5.26656882e-01],
#        [-8.16496581e-01, -6.54653671e-01,  1.52752523e+00,
#          0.00000000e+00, -1.07356980e+00],
#        [ 1.22474487e+00, -6.54653671e-01, -6.54653671e-01,
#          1.34013983e+00,  1.38753832e+00],
#        [-8.16496581e-01,  1.52752523e+00, -6.54653671e-01,
#          1.63077256e+00,  1.75214693e+00],
# ...

# %% [markdown]
# Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('/content/D5data1.csv')
dataset
#
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
dataset.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
plt.scatter(X_train,y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.show()

# %%
#Regressor coefficient
regressor.coef_
# Out:
# array([9312.57512673])

# %%
# y_intercept
regressor.intercept_
# Out:
# np.float64(26780.09915062818)
